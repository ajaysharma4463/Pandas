# %%
import pandas as pd
pokemon=pd.read_excel(r"C:\Users\Ajay\Desktop\pokemon_data.xlsx")
pokemon
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
pokemon.set_index("Name")
# Out:
#                          #   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur                1    Grass  Poison  45      49       49       65
# Ivysaur                  2    Grass  Poison  60      62       63       80
# Venusaur                 3    Grass  Poison  80      82       83      100
# VenusaurMega Venusaur    3    Grass  Poison  80     100      123      122
# Charmander               4     Fire     NaN  39      52       43       60
# ...                    ...      ...     ...  ..     ...      ...      ...
# Diancie                719     Rock   Fairy  50     100      150      100
# DiancieMega Diancie    719     Rock   Fairy  50     160      110      160
# HoopaHoopa Confined    720  Psychic   Ghost  80     110       60      150
# HoopaHoopa Unbound     720  Psychic    Dark  80     160       60      170
# Volcanion              721     Fire   Water  80     110      120      130
#
#                        Sp. Def  Speed  Generation  Legendary
# Name
# ...

# %%
pokemon.set_index("Type 1")
# Out:
#            #                   Name  Type 2  HP  Attack  Defense  Sp. Atk  \
# Type 1
# Grass      1              Bulbasaur  Poison  45      49       49       65
# Grass      2                Ivysaur  Poison  60      62       63       80
# Grass      3               Venusaur  Poison  80      82       83      100
# Grass      3  VenusaurMega Venusaur  Poison  80     100      123      122
# Fire       4             Charmander     NaN  39      52       43       60
# ...      ...                    ...     ...  ..     ...      ...      ...
# Rock     719                Diancie   Fairy  50     100      150      100
# Rock     719    DiancieMega Diancie   Fairy  50     160      110      160
# Psychic  720    HoopaHoopa Confined   Ghost  80     110       60      150
# Psychic  720     HoopaHoopa Unbound    Dark  80     160       60      170
# Fire     721              Volcanion   Water  80     110      120      130
#
#          Sp. Def  Speed  Generation  Legendary
# Type 1
# ...

# %%
pokemon.set_index(["Name","Type 2"])
# Out:
#                                 #   Type 1  HP  Attack  Defense  Sp. Atk  \
# Name                  Type 2
# Bulbasaur             Poison    1    Grass  45      49       49       65
# Ivysaur               Poison    2    Grass  60      62       63       80
# Venusaur              Poison    3    Grass  80      82       83      100
# VenusaurMega Venusaur Poison    3    Grass  80     100      123      122
# Charmander            NaN       4     Fire  39      52       43       60
# ...                           ...      ...  ..     ...      ...      ...
# Diancie               Fairy   719     Rock  50     100      150      100
# DiancieMega Diancie   Fairy   719     Rock  50     160      110      160
# HoopaHoopa Confined   Ghost   720  Psychic  80     110       60      150
# HoopaHoopa Unbound    Dark    720  Psychic  80     160       60      170
# Volcanion             Water   721     Fire  80     110      120      130
#
# ...

# %%
pokemon.set_index(keys=["Name","Type 2"])
# Out:
#                                 #   Type 1  HP  Attack  Defense  Sp. Atk  \
# Name                  Type 2
# Bulbasaur             Poison    1    Grass  45      49       49       65
# Ivysaur               Poison    2    Grass  60      62       63       80
# Venusaur              Poison    3    Grass  80      82       83      100
# VenusaurMega Venusaur Poison    3    Grass  80     100      123      122
# Charmander            NaN       4     Fire  39      52       43       60
# ...                           ...      ...  ..     ...      ...      ...
# Diancie               Fairy   719     Rock  50     100      150      100
# DiancieMega Diancie   Fairy   719     Rock  50     160      110      160
# HoopaHoopa Confined   Ghost   720  Psychic  80     110       60      150
# HoopaHoopa Unbound    Dark    720  Psychic  80     160       60      170
# Volcanion             Water   721     Fire  80     110      120      130
#
# ...

# %%
pokemon.sort_index()
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
pokemon.index
# Out:
# RangeIndex(start=0, stop=800, step=1)

# %%
type(pokemon.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
pokemon.index[0]
# Out:
# 0

# %%
pokemon.set_index("Name",inplace=True)

# %%
pokemon.index[0]
# Out:
# 'Bulbasaur'

# %%
type(pokemon.index)
# Out:
# pandas.core.indexes.base.Index

# %%
pokemon.reset_index()
# Out:
#                       Name    #   Type 1  Type 2  HP  Attack  Defense  \
# 0                Bulbasaur    1    Grass  Poison  45      49       49
# 1                  Ivysaur    2    Grass  Poison  60      62       63
# 2                 Venusaur    3    Grass  Poison  80      82       83
# 3    VenusaurMega Venusaur    3    Grass  Poison  80     100      123
# 4               Charmander    4     Fire     NaN  39      52       43
# ..                     ...  ...      ...     ...  ..     ...      ...
# 795                Diancie  719     Rock   Fairy  50     100      150
# 796    DiancieMega Diancie  719     Rock   Fairy  50     160      110
# 797    HoopaHoopa Confined  720  Psychic   Ghost  80     110       60
# 798     HoopaHoopa Unbound  720  Psychic    Dark  80     160       60
# 799              Volcanion  721     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
pokemon.set_index(keys=["Type 2","Type 1"],inplace=True)

# %%
pokemon.index[0]
# Out:
# ('Poison', 'Grass')

# %%
type(pokemon.index)  # now we used multiple indec so, as a result it shows Multiinddex in output
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
pokemon.index
# Out:
# MultiIndex([('Poison',   'Grass'),
#             ('Poison',   'Grass'),
#             ('Poison',   'Grass'),
#             ('Poison',   'Grass'),
#             (     nan,    'Fire'),
#             (     nan,    'Fire'),
#             ('Flying',    'Fire'),
#             ('Dragon',    'Fire'),
#             ('Flying',    'Fire'),
#             (     nan,   'Water'),
#             ...
#             ('Dragon',  'Flying'),
#             ('Dragon',  'Flying'),
#             (     nan,   'Fairy'),
#             ('Flying',    'Dark'),
#             ('Ground',  'Dragon'),
#             ( 'Fairy',    'Rock'),
#             ( 'Fairy',    'Rock'),
#             ( 'Ghost', 'Psychic'),
#             (  'Dark', 'Psychic'),
#             ( 'Water',    'Fire')],
#            names=['Type 2', 'Type 1'], length=800)

# %% [markdown]
# # .index.get_level_values()

# %%
# when we have huge data so work with sorting  sort_values()
# now we will fech index 
pokemon.index.get_level_values(0)
# Out:
# Index(['Poison', 'Poison', 'Poison', 'Poison',      nan,      nan, 'Flying',
#        'Dragon', 'Flying',      nan,
#        ...
#        'Dragon', 'Dragon',      nan, 'Flying', 'Ground',  'Fairy',  'Fairy',
#         'Ghost',   'Dark',  'Water'],
#       dtype='object', name='Type 2', length=800)

# %%
pokemon.index.get_level_values(1)
# Out:
# Index(['Grass', 'Grass', 'Grass', 'Grass', 'Fire', 'Fire', 'Fire', 'Fire',
#        'Fire', 'Water',
#        ...
#        'Flying', 'Flying', 'Fairy', 'Dark', 'Dragon', 'Rock', 'Rock',
#        'Psychic', 'Psychic', 'Fire'],
#       dtype='object', name='Type 1', length=800)

# %%
pokemon.index.get_level_values("Type 1")
# Out:
# Index(['Grass', 'Grass', 'Grass', 'Grass', 'Fire', 'Fire', 'Fire', 'Fire',
#        'Fire', 'Water',
#        ...
#        'Flying', 'Flying', 'Fairy', 'Dark', 'Dragon', 'Rock', 'Rock',
#        'Psychic', 'Psychic', 'Fire'],
#       dtype='object', name='Type 1', length=800)

# %%
pokemon.index.get_level_values("Type 2")
# Out:
# Index(['Poison', 'Poison', 'Poison', 'Poison',      nan,      nan, 'Flying',
#        'Dragon', 'Flying',      nan,
#        ...
#        'Dragon', 'Dragon',      nan, 'Flying', 'Ground',  'Fairy',  'Fairy',
#         'Ghost',   'Dark',  'Water'],
#       dtype='object', name='Type 2', length=800)

# %% [markdown]
# # .index.set_names()

# %%
pokemon.index.set_names(["Type 1","Type 23"],inplace=True)

# %%
pokemon #3 insex has been changed
# Out:
#                   #  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Type 1 Type 23
# Poison Grass      1  45      49       49       65       65     45           1
#        Grass      2  60      62       63       80       80     60           1
#        Grass      3  80      82       83      100      100     80           1
#        Grass      3  80     100      123      122      120     80           1
# NaN    Fire       4  39      52       43       60       50     65           1
# ...             ...  ..     ...      ...      ...      ...    ...         ...
# Fairy  Rock     719  50     100      150      100      150     50           6
#        Rock     719  50     160      110      160      110    110           6
# Ghost  Psychic  720  80     110       60      150      130     70           6
# Dark   Psychic  720  80     160       60      170      130     80           6
# Water  Fire     721  80     110      120      130       90     70           6
#
# ...

# %% [markdown]
# # .sort_index()

# %%
pokemon.sort_index()  # so basically we have two  index  so , npth od the index will be sort in ascending order
# Out:
#                    #   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1 Type 23
# Bug    Poison    451   40      50       90       30       55     65
#        Rock      347   45      95       50       40       50     75
#        Rock      348   75     125      100       70       80     45
# Dark   Fighting  675   95     124       78       69       71     58
#        Ghost     442   50      92      108       92      108     35
# ...              ...  ...     ...      ...      ...      ...    ...
# NaN    Water     594  165      75       80       40       45     65
#        Water     656   41      56       40       62       44     71
#        Water     657   54      63       52       83       56     97
#        Water     692   50      53       62       58       63     44
#        Water     693   71      73       88      120       89     59
#
#                  Generation  Legendary
# Type 1 Type 23
# Bug    Poison             4      False
# ...

# %%
pokemon.sort_index(ascending=[True,False])  # we provide sort index value fasle for Type 23 column
# Out:
#                   #  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Type 1 Type 23
# Bug    Rock     347  45      95       50       40       50     75           3
#        Rock     348  75     125      100       70       80     45           3
#        Poison   451  40      50       90       30       55     65           4
# Dark   Water    130  95     155      109       70      130     81           1
#        Water    318  45      90       20       65       20     65           3
# ...             ...  ..     ...      ...      ...      ...    ...         ...
# NaN    Bug      588  50      75       45       40       45     60           5
#        Bug      616  50      40       85       40       65     25           5
#        Bug      617  80      70       40      100       60    145           5
#        Bug      664  38      35       40       27       25     35           6
#        Bug      665  45      22       60       27       30     29           6
#
# ...

# %%
# and we see  huge gap in Type 1 , its means Rock, Poison is matched with Bug

# %% [markdown]
# # extract rows from multindex

# %%
pokemon.loc[("Type 1","Type 23")]  # usually it work ,but it is showing error
#List does not work in it so i used tuple
# Out:
# C:\Users\Ajay\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Type 1'
#
# ...

# %%
pokemon.ix[("Type 1","Type 23")]  # still showing error
# Out:
# C:\Users\Ajay\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# C:\Users\Ajay\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# ...

# %% [markdown]
# # .transpose()

# %%
pokemon.transpose() # it transpose all data
# Out:
# Type 1     Poison                         NaN        Flying Dragon Flying  \
# Type 23     Grass  Grass  Grass  Grass   Fire   Fire   Fire   Fire   Fire
# #               1      2      3      3      4      5      6      6      6
# HP             45     60     80     80     39     58     78     78     78
# Attack         49     62     82    100     52     64     84    130    104
# Defense        49     63     83    123     43     58     78    111     78
# Sp. Atk        65     80    100    122     60     80    109    130    159
# Sp. Def        65     80    100    120     50     65     85     85    115
# Speed          45     60     80     80     65     80    100    100    100
# Generation      1      1      1      1      1      1      1      1      1
# Legendary   False  False  False  False  False  False  False  False  False
#
# Type 1        NaN  ... Dragon          NaN Flying Ground Fairy         Ghost  \
# ...

# %% [markdown]
# # .swaplevel()

# %%
pokemon.swaplevel()  # index intercange
# Out:
#                   #  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Type 23 Type 1
# Grass   Poison    1  45      49       49       65       65     45           1
#         Poison    2  60      62       63       80       80     60           1
#         Poison    3  80      82       83      100      100     80           1
#         Poison    3  80     100      123      122      120     80           1
# Fire    NaN       4  39      52       43       60       50     65           1
# ...             ...  ..     ...      ...      ...      ...    ...         ...
# Rock    Fairy   719  50     100      150      100      150     50           6
#         Fairy   719  50     160      110      160      110    110           6
# Psychic Ghost   720  80     110       60      150      130     70           6
#         Dark    720  80     160       60      170      130     80           6
# Fire    Water   721  80     110      120      130       90     70           6
#
# ...

# %% [markdown]
# # .stack()

# %%
pokemon.stack()   # column to rows
# Out:
# Type 1  Type 23
# Poison  Grass    #                1
#                  HP              45
#                  Attack          49
#                  Defense         49
#                  Sp. Atk         65
#                                ...
# Water   Fire     Sp. Atk        130
#                  Sp. Def         90
#                  Speed           70
#                  Generation       6
#                  Legendary     True
# Length: 7200, dtype: object

# %%
s=pokemon.stack().to_frame()

# %%
s.unstack() # rows to column  
# but it is not working ,i dont know why
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-253e1b063a2b> in <module>
# ----> 1 s.unstack().unstack()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in unstack(self, level, fill_value)
#    6376         from pandas.core.reshape.reshape import unstack
#    6377
# -> 6378         return unstack(self, level, fill_value)
#    6379
#    6380     _shared_docs[
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in unstack(obj, level, fill_value)
#     410     if isinstance(obj, DataFrame):
#     411         if isinstance(obj.index, MultiIndex):
# --> 412             return _unstack_frame(obj, level, fill_value=fill_value)
#     413         else:
#     414             return obj.T.stack(dropna=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in _unstack_frame(obj, level, fill_value)
# ...

# %%
# i left unstack video , becasue it is not working
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-2f79ce5dad51> in <module>
# ----> 1 s.unstack(0)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in unstack(self, level, fill_value)
#    6376         from pandas.core.reshape.reshape import unstack
#    6377
# -> 6378         return unstack(self, level, fill_value)
#    6379
#    6380     _shared_docs[
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in unstack(obj, level, fill_value)
#     410     if isinstance(obj, DataFrame):
#     411         if isinstance(obj.index, MultiIndex):
# --> 412             return _unstack_frame(obj, level, fill_value=fill_value)
#     413         else:
#     414             return obj.T.stack(dropna=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in _unstack_frame(obj, level, fill_value)
# ...

# %% [markdown]
# # .pivot()

# %%
pokemon.reset_index()
# Out:
#      Type 1  Type 23    #  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0    Poison    Grass    1  45      49       49       65       65     45
# 1    Poison    Grass    2  60      62       63       80       80     60
# 2    Poison    Grass    3  80      82       83      100      100     80
# 3    Poison    Grass    3  80     100      123      122      120     80
# 4       NaN     Fire    4  39      52       43       60       50     65
# ..      ...      ...  ...  ..     ...      ...      ...      ...    ...
# 795   Fairy     Rock  719  50     100      150      100      150     50
# 796   Fairy     Rock  719  50     160      110      160      110    110
# 797   Ghost  Psychic  720  80     110       60      150      130     70
# 798    Dark  Psychic  720  80     160       60      170      130     80
# 799   Water     Fire  721  80     110      120      130       90     70
#
#      Generation  Legendary
# 0             1      False
# 1             1      False
# ...

# %%
pokemon.pivot(index="HP",columns="Attack",values="Speed")   the code is fine bt still giving error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-2109053a4e22> in <module>
# ----> 1 pokemon.pivot(index="HP",columns="Attack",values="Speed")
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    5917         from pandas.core.reshape.pivot import pivot
#    5918
# -> 5919         return pivot(self, index=index, columns=columns, values=values)
#    5920
#    5921     _shared_docs[
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot(data, index, columns, values)
#     428         else:
#     429             indexed = data._constructor_sliced(data[values].values, index=index)
# --> 430     return indexed.unstack(columns)
#     431
#     432
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in unstack(self, level, fill_value)
#    3743         from pandas.core.reshape.reshape import unstack
# ...

# %%
pd.melt(pokemon,id_vars="Attack")
# Out:
#       Attack   variable value
# 0         49          #     1
# 1         62          #     2
# 2         82          #     3
# 3        100          #     3
# 4         52          #     4
# ...      ...        ...   ...
# 6395     100  Legendary  True
# 6396     160  Legendary  True
# 6397     110  Legendary  True
# 6398     160  Legendary  True
# 6399     110  Legendary  True
#
# [6400 rows x 3 columns]
