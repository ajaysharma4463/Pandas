# %%
#i think before working to any dataset we need to fix it pronlem like currency, rensering ,duplication etc

# %%
Esc+B

# %%
import pandas as pd
pokemon=pd.read_excel(r"C:\Users\Ajay\Desktop\pokemon_data.xlsx")
pokemon
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
pokemon.head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
# #             800 non-null int64
# Name          800 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
# pandas does not know currency   like value is $2000.00  it is Object(string) but pandas does not know that 
#  it should be in float datatype

# %%
pokemon["Type 1"].nunique()  # number of unique value in pokemon datas et which has a800 row
# we can chage into category data type 
#category datatype is used when number of items are less but it is stored in multiple column so basically it is using memory
# Out:
# 18

# %%
pokemon["Type 1"]=pokemon["Type 1"].astype("category")

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
# #             800 non-null int64
# Name          800 non-null object
# Type 1        800 non-null category
# Type 2        414 non-null object
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), category(1), int64(8), object(2)
# memory usage: 65.0+ KB

# %%
# see the memory

# %% [markdown]
# # common string method .lower(),upper(),title() and .len()

# %%
"hello world".upper()
# Out:
# 'HELLO WORLD'

# %%
"hello world".title() # first letter will be  upper
# Out:
# 'Hello World'

# %%
len("hello world")
# Out:
# 11

# %%
pokemon["Name"].title()  # error will give
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-4c9c872ed93b> in <module>
# ----> 1 pokemon["Name"].title()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'title'

# %%
pokemon["Name"].str.title()  # when we have a series then we need to use string(str) and then use function
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      Venusaurmega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      Dianciemega Diancie
# 797      Hoopahoopa Confined
# 798       Hoopahoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
pokemon["Name"].str.lower().str.upper()  # when i use lower it turn to lower and now i used upper
# Out:
# 0                  BULBASAUR
# 1                    IVYSAUR
# 2                   VENUSAUR
# 3      VENUSAURMEGA VENUSAUR
# 4                 CHARMANDER
#                ...
# 795                  DIANCIE
# 796      DIANCIEMEGA DIANCIE
# 797      HOOPAHOOPA CONFINED
# 798       HOOPAHOOPA UNBOUND
# 799                VOLCANION
# Name: Name, Length: 800, dtype: object

# %%
pokemon["Name"]
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
len(pokemon["Name"])
# Out:
# 800

# %%
pokemon["Name"].str.len() # showing size of each name
# Out:
# 0       9
# 1       7
# 2       8
# 3      21
# 4      10
#        ..
# 795     7
# 796    19
# 797    19
# 798    18
# 799     9
# Name: Name, Length: 800, dtype: int64

# %% [markdown]
# # .str.replace() method

# %%
"Hello World".replace("l","pppp")   # basic python
# Out:
# 'Heppppppppo Worppppd'

# %%
# lets work with series ,what would be the resul
pokemon["Name"].str.replace("iam","space")
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
 # if i had slary method then i would replace like this
    pokemon["Salary"].str.replace("$","").astype('float')  
    # converting $ to nothing and cahging in to dloat datatype rather than string or object

# %%
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
pokemon["Speed"].sum()
# Out:
# 54622

# %%
pokemon["Speed"].std()
# Out:
# 29.06047371716149

# %%
pokemon["Speed"].mean()
# Out:
# 68.2775

# %%
pokemon["Speed"].nlargest(3)
# Out:
# 431    180
# 315    160
# 71     150
# Name: Speed, dtype: int64

# %%
pokemon["Speed"].nsmallest(2)
# Out:
# 230    5
# 495    5
# Name: Speed, dtype: int64

# %% [markdown]
# # filtering with string method

# %%
# for filtering we to genrate boolean series

# if we want to fing something like string f.first, we nned to convert data into upper or lower so
#that our check condition would not fail even value present in t
#becasue K sensitive is happeing in this

# %%
pokemon["Name"].str.lower()
# Out:
# 0                  bulbasaur
# 1                    ivysaur
# 2                   venusaur
# 3      venusaurmega venusaur
# 4                 charmander
#                ...
# 795                  diancie
# 796      dianciemega diancie
# 797      hoopahoopa confined
# 798       hoopahoopa unbound
# 799                volcanion
# Name: Name, Length: 800, dtype: object

# %%
bool=pokemon["Name"].str.lower().str.contains("bulbasaur")
pokemon[bool]  # use contains method  for filtering in this we have one pokemon name
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
#
#    Generation  Legendary
# 0           1      False

# %%
pokemon[pokemon["Name"].str.lower().str.startswith("bu")]  # we can use startswith method
# Out:
#        #        Name  Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0      1   Bulbasaur   Grass  Poison  45      49       49       65       65
# 15    12  Butterfree     Bug  Flying  60      45       50       90       80
# 451  406       Budew   Grass  Poison  40      30       35       50       70
# 457  412       Burmy     Bug     NaN  40      29       45       29       45
# 465  418      Buizel   Water     NaN  55      65       35       60       30
# 474  427     Buneary  Normal     NaN  55      66       44       44       56
# 727  659    Bunnelby  Normal     NaN  38      36       38       32       36
#
#      Speed  Generation  Legendary
# 0       45           1      False
# 15      70           1      False
# 451     55           4      False
# 457     36           4      False
# 465     85           4      False
# 474     85           4      False
# 727     57           6      False

# %%
pokemon[pokemon["Name"].str.lower().str.endswith("ur")] # use endswith method
# Out:
#        #                   Name  Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur   Grass  Poison  45      49       49       65
# 1      2                Ivysaur   Grass  Poison  60      62       63       80
# 2      3               Venusaur   Grass  Poison  80      82       83      100
# 3      3  VenusaurMega Venusaur   Grass  Poison  80     100      123      122
# 246  228               Houndour    Dark    Fire  45      60       30       80
# 317  293                Whismur  Normal     NaN  64      51       23       51
# 574  515                Panpour   Water     NaN  50      53       48       53
# 575  516               Simipour   Water     NaN  75      98       63       98
# 588  529                Drilbur  Ground     NaN  60      85       40       30
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# 1         80     60           1      False
# 2        100     80           1      False
# ...

# %% [markdown]
# # more string function .strip() ,.lstrip(),.rstrip()

# %%
# for removal of white spaces we use this method

# %%
len("        Hello world  ") # 21 length becasue of extra white spaces  in starting and the end , that can done by lstrip and
#rdtrip method
# Out:
# 21

# %%
"        Hello world  ".lstrip()
# Out:
# 'Hello world  '

# %%
"Hello world  ".rstrip()
# Out:
# 'Hello world'

# %%
"    Hello world  ".strip()  #combination of both
# Out:
# 'Hello world'

# %%
pokemon["Name"]   alt+enter to run in jupyter notebook
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
pokemon["Name"]=pokemon["Name"].str.strip()

# %%
pokemon
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# use alwasys to  remove whitespaces and good for memory

# %% [markdown]
# # string method on index and columns label

# %%
pokemon=pd.read_excel(r"C:\Users\Ajay\Desktop\pokemon_data.xlsx",index_col="Name")
pokemon
# Out:
#                          #   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur                1    Grass  Poison  45      49       49       65
# Ivysaur                  2    Grass  Poison  60      62       63       80
# Venusaur                 3    Grass  Poison  80      82       83      100
# VenusaurMega Venusaur    3    Grass  Poison  80     100      123      122
# Charmander               4     Fire     NaN  39      52       43       60
# ...                    ...      ...     ...  ..     ...      ...      ...
# Diancie                719     Rock   Fairy  50     100      150      100
# DiancieMega Diancie    719     Rock   Fairy  50     160      110      160
# HoopaHoopa Confined    720  Psychic   Ghost  80     110       60      150
# HoopaHoopa Unbound     720  Psychic    Dark  80     160       60      170
# Volcanion              721     Fire   Water  80     110      120      130
#
#                        Sp. Def  Speed  Generation  Legendary
# Name
# ...

# %%
pokemon.index    # list of all index  in array
# Out:
# Index(['Bulbasaur', 'Ivysaur', 'Venusaur', 'VenusaurMega Venusaur',
#        'Charmander', 'Charmeleon', 'Charizard', 'CharizardMega Charizard X',
#        'CharizardMega Charizard Y', 'Squirtle',
#        ...
#        'Noibat', 'Noivern', 'Xerneas', 'Yveltal', 'Zygarde50% Forme',
#        'Diancie', 'DiancieMega Diancie', 'HoopaHoopa Confined',
#        'HoopaHoopa Unbound', 'Volcanion'],
#       dtype='object', name='Name', length=800)

# %%
pokemon.index=pokemon.index.str.strip().str.lower()

# %%
pokemon.head(3)  # stripping has been done and all words are formatted into lower case
# Out:
#            # Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# bulbasaur  1  Grass  Poison  45      49       49       65       65     45
# ivysaur    2  Grass  Poison  60      62       63       80       80     60
# venusaur   3  Grass  Poison  80      82       83      100      100     80
#
#            Generation  Legendary
# Name
# bulbasaur           1      False
# ivysaur             1      False
# venusaur            1      False

# %%
pokemon.columns=pokemon.columns.str.strip().str.upper()

# %%
pokemon.columns  # all are chaged into capital letters
# Out:
# Index(['#', 'TYPE 1', 'TYPE 2', 'HP', 'ATTACK', 'DEFENSE', 'SP. ATK',
#        'SP. DEF', 'SPEED', 'GENERATION', 'LEGENDARY'],
#       dtype='object')

# %% [markdown]
# # .split method for string

# %%
"My Name is Ajay Sharma".split(" ")  # it split the string by delimeter (space) and combine the result in list with comma
# Out:
# ['My', 'Name', 'is', 'Ajay', 'Sharma']

# %%
# lets try with series
pokemon=pd.read_excel(r"C:\Users\Ajay\Desktop\pokemon_data.xlsx")
pokemon ["Name"].str.split(" ")  # Name is split in half if surname is presnt with comma which denote list
# Out:
# 0                   [Bulbasaur]
# 1                     [Ivysaur]
# 2                    [Venusaur]
# 3      [VenusaurMega, Venusaur]
# 4                  [Charmander]
#                  ...
# 795                   [Diancie]
# 796      [DiancieMega, Diancie]
# 797      [HoopaHoopa, Confined]
# 798       [HoopaHoopa, Unbound]
# 799                 [Volcanion]
# Name: Name, Length: 800, dtype: object

# %%
pokemon ["Name"].str.split(" ").str.get(0).str.title()
# Out:
# 0         Bulbasaur
# 1           Ivysaur
# 2          Venusaur
# 3      Venusaurmega
# 4        Charmander
#            ...
# 795         Diancie
# 796     Dianciemega
# 797      Hoopahoopa
# 798      Hoopahoopa
# 799       Volcanion
# Name: Name, Length: 800, dtype: object

# %%
pokemon ["Name"].str.split(" ").str.get(0).str.title().value_counts()
# get method provide suranme which have surname other it is aalso provideing firstname with index 0
# calue_counts() methos print number of total occurance
# Out:
# Nidoran          2
# Mewtwomega       2
# Hoopahoopa       2
# Charizardmega    2
# Venusaurmega     1
#                 ..
# Altariamega      1
# Meloettaaria     1
# Cranidos         1
# Mr.              1
# Weavile          1
# Name: Name, Length: 796, dtype: int64

# %%
# what we have firatname with two 2 words than learn this logic
pokemon["Name"].str.split(",").str.get(1).str.strip().str.split(" ").str.get(0)

# %% [markdown]
# # expand method in split method

# %%
pokemon["Name"].str.split(" ",expand=True)
# so three row are coming  looks like datafram
# so we need to store tham
# Out:
#                 0         1     2
# 0       Bulbasaur      None  None
# 1         Ivysaur      None  None
# 2        Venusaur      None  None
# 3    VenusaurMega  Venusaur  None
# 4      Charmander      None  None
# ..            ...       ...   ...
# 795       Diancie      None  None
# 796   DiancieMega   Diancie  None
# 797    HoopaHoopa  Confined  None
# 798    HoopaHoopa   Unbound  None
# 799     Volcanion      None  None
#
# [800 rows x 3 columns]

# %%
pokemon[["Firstname","middlename","lastname"]]=pokemon["Name"].str.split(" ",expand=True)

# %%
pokemon
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary     Firstname middlename  \
# ...

# %%
# we can restict our split by addiig n in it
pokemon[["Firstname","lastname"]]=pokemon["Name"].str.split(" ",expand=True,n=1)

# %%
pokemon  # but i had madde column earlier so thats why it is showing 3 column we need to drop these column first
del pokemon["Firstname"]

# %%
pokemon
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary middlename  lastname
# ...

# %%
del pokemon["middlename"]  # we canoot delete multiple column
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'middlename'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-93-a47bbdf0032f> in <module>
# ...

# %%
del pokemon["lastname"]

# %%
pokemon[["Firstname","lastname"]]=pokemon["Name"].str.split(" ",expand=True,n=1)

# %%
pokemon # now it is working
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary     Firstname  lastname
# ...
