# %%
import pandas as pd
pokemon=pd.read_excel(r"C:\Users\Ajay\Desktop\pokemon_data.xlsx")
pokemon
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# #  .astype() function

# %%
# we will convet datatype to another database
# to decrease in memory
# and increase in spped
pokemon["Legendary"].dtype  # for single column
pokemon.dtypes  # for all column
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
pokemon.info()   # no null value
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
# #             800 non-null int64
# Name          800 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
# if my shet has NaN value in it then first i need to remove those null value if i want to convert datatypes
# it only work if my sheet has no null values
# pandas he unique datatypes which is not n pythpn (category)
# use of category is , if we have dupliate value in one column over million row then we can chage therir type to category
# to reduced memory
pokemon["Legendary"].astype("category")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795     True
# 796     True
# 797     True
# 798     True
# 799     True
# Name: Legendary, Length: 800, dtype: category
# Categories (2, object): [False, True]

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
# #             800 non-null int64
# Name          800 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
pokemon["Legendary"]=pokemon["Legendary"].astype("category")

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
# #             800 non-null int64
# Name          800 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null category
# dtypes: category(1), int64(8), object(3)
# memory usage: 69.8+ KB

# %%
pokemon
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation Legendary
# 0         65       65     45           1     False
# ...

# %%
pokemon["HP"]=pokemon["HP"].astype("int")
pokemon["Attack"]=pokemon["Attack"].astype("int")
pokemon["Defense"]=pokemon["Defense"].astype("int")
pokemon["Speed"]=pokemon["Speed"].astype("int")

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
# #             800 non-null int64
# Name          800 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# HP            800 non-null int32
# Attack        800 non-null int32
# Defense       800 non-null int32
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int32
# Generation    800 non-null int64
# Legendary     800 non-null category
# dtypes: category(1), int32(4), int64(4), object(3)
# memory usage: 57.2+ KB

# %%
# memory is changed that very effective
pokemon["HP"].nunique()  # 94 unique value in HP column
# Out:
# 94

# %%
pokemon["HP"]=pokemon["HP"].astype("int") # astype has no inplace  attribut to save the chages so thats why we use assignment

# %% [markdown]
# #  .sort_values in dataframes

# %%
pokemon.sort_values("Name") # i use "by" parameter in name to tell python i need to change ina scending order
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation Legendary
# ...

# %%
# if our dataframes has null values in it then python automatically put in last when we use .sort_values function in it
#we can change to first
pokemon.sort_values("Name",na_position="last")   # this id by dault in pandas
pokemon.sort_values("Name",na_position="first")  # this is wrking but my datafram has no null value 
#thats why it is not showing any updates
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation Legendary
# ...

# %% [markdown]
# # .sort_vlaues in multiple coloumn

# %%
pokemon.sort_values(["HP","Attack"],ascending=False)
# Out:
#        #       Name   Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 261  242    Blissey   Normal    NaN  255      10       10       75      135
# 121  113    Chansey   Normal    NaN  250       5        5       35      105
# 217  202  Wobbuffet  Psychic    NaN  190      33       58       33       58
# 351  321    Wailord    Water    NaN  170      90       45       90       45
# 655  594  Alomomola    Water    NaN  165      75       80       40       45
# ..   ...        ...      ...    ...  ...     ...      ...      ...      ...
# 381  349     Feebas    Water    NaN   20      15       20       10       55
# 139  129   Magikarp    Water    NaN   20      10       55       15       20
# 230  213    Shuckle      Bug   Rock   20      10      230       10      230
# 55    50    Diglett   Ground    NaN   10      55       25       35       45
# 316  292   Shedinja      Bug  Ghost    1      90       45       30       30
#
#      Speed  Generation Legendary
# ...

# %%
pokemon.sort_values(["HP","Attack"],ascending=[False,False]) # same result
# Out:
#        #       Name   Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 261  242    Blissey   Normal    NaN  255      10       10       75      135
# 121  113    Chansey   Normal    NaN  250       5        5       35      105
# 217  202  Wobbuffet  Psychic    NaN  190      33       58       33       58
# 351  321    Wailord    Water    NaN  170      90       45       90       45
# 655  594  Alomomola    Water    NaN  165      75       80       40       45
# ..   ...        ...      ...    ...  ...     ...      ...      ...      ...
# 381  349     Feebas    Water    NaN   20      15       20       10       55
# 139  129   Magikarp    Water    NaN   20      10       55       15       20
# 230  213    Shuckle      Bug   Rock   20      10      230       10      230
# 55    50    Diglett   Ground    NaN   10      55       25       35       45
# 316  292   Shedinja      Bug  Ghost    1      90       45       30       30
#
#      Speed  Generation Legendary
# ...

# %%
pokemon.sort_values(["HP","Attack"],ascending=[False,True])  # we can change it
# Out:
#        #       Name    Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 261  242    Blissey    Normal    NaN  255      10       10       75      135
# 121  113    Chansey    Normal    NaN  250       5        5       35      105
# 217  202  Wobbuffet   Psychic    NaN  190      33       58       33       58
# 351  321    Wailord     Water    NaN  170      90       45       90       45
# 655  594  Alomomola     Water    NaN  165      75       80       40       45
# ..   ...        ...       ...    ...  ...     ...      ...      ...      ...
# 487  439   Mime Jr.   Psychic  Fairy   20      25       45       70       90
# 186  172      Pichu  Electric    NaN   20      40       15       35       35
# 388  355    Duskull     Ghost    NaN   20      40       90       30       90
# 55    50    Diglett    Ground    NaN   10      55       25       35       45
# 316  292   Shedinja       Bug  Ghost    1      90       45       30       30
#
#      Speed  Generation Legendary
# ...

# %% [markdown]
# # .sort_index() method

# %%
pokemon.sort_index()  # it will sort in ascending by default
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation Legendary
# 0         65       65     45           1     False
# ...

# %%
pokemon["new speed"]=pokemon["Speed"].rank().astype("int")
pokemon
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation Legendary  new speed
# 0         65       65     45           1     False        191
# ...

# %%
pokemon["Speed"]=pokemon["Speed"].sort_values(ascending=False)
pokemon
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation Legendary  new speed
# 0         65       65     45           1     False        191
# ...

# %%
pokemon["new speed"]=pokemon["new speed"].sort_values()

# %%
pokemon
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation Legendary  new speed
# 0         65       65     45           1     False        191
# ...

# %% [markdown]
# # differnt ways optimization of data fream

# %%
# in our dataframe does not have  date  related record but if we have then we can use  function
pd.to_datetime(pokemon["Attack"])   # we change it into datetime
# Out:
# 0     1970-01-01 00:00:00.000000049
# 1     1970-01-01 00:00:00.000000062
# 2     1970-01-01 00:00:00.000000082
# 3     1970-01-01 00:00:00.000000100
# 4     1970-01-01 00:00:00.000000052
#                    ...
# 795   1970-01-01 00:00:00.000000100
# 796   1970-01-01 00:00:00.000000160
# 797   1970-01-01 00:00:00.000000110
# 798   1970-01-01 00:00:00.000000160
# 799   1970-01-01 00:00:00.000000110
# Name: Attack, Length: 800, dtype: datetime64[ns]

# %%
# another way to convert to datetime is:
pokemon=pd.read_excel(r"C:\Users\Ajay\Desktop\pokemon_data.xlsx",parse_dates=["Attack"])
pokemon
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# we can use category data type in Gender column
# cange their datatypes to int  to reduce size

# %% [markdown]
# #  use Filter

# %%
pokemon["Type 1"]=="Grass"  # first it will check the condition and will return boolean value
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Type 1, Length: 800, dtype: bool

# %%
pokemon[pokemon["Type 1"]=="Grass"]  # now inside square bracket it eill give data to outside pokemon to see only wich has Grass
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
pokemon  # previous action is not permanent
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# another way to check
new=pokemon["Type 1"]=="Grass"

# %%
pokemon[new]  # put another value  in another vaiablr and pass in with pokemon
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# # filter  multiple column with AND

# %%
# for multiple column check i strongly recommend use variable to store
new=pokemon["Type 1"]=="Grass"
new1=pokemon["Type 2"]=="Poison"

# %%
pokemon[new & new1] # True boolean will return
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 48    43                 Oddish  Grass  Poison   45      50       55       75
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 75    69             Bellsprout  Grass  Poison   50      75       35       70
# 76    70             Weepinbell  Grass  Poison   65      90       50       85
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 344  315                Roselia  Grass  Poison   50      60       45      100
# ...

# %% [markdown]
# # filter  multiple column with OR

# %%
# atleast one condition should be correct , it is not like with AND
pokemon[new | new1]  # row is excedded
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 16    13                 Weedle    Bug    Poison   40      35       30
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
new=pokemon["Type 1"]=="Grass"
new1=pokemon["Type 2"]=="Poison"
new3=pokemon["Legendary"]==True

# %%
pokemon[(new & new1) & new3 ]  # no result becasue no mattching row 
# i strongly recooment to use variable to do this thing
# bracket will excedute first
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary]
# Index: []

# %% [markdown]
# # isin() method

# %%
# when we have multiple cndition to check uase .isin() function
#new=pokemon["Type 1"]=="Grass"
#new1=pokemon["Type 2"]=="Poison"
#new3=pokemon["Legendary"]==True

#rather than writing these conition
new=pokemon["Type 1"].isin(["Grass","Rock"])
pokemon[new]  # focus on one column and put condition in it
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 48    43                 Oddish  Grass  Poison   45      50       55       75
# ..   ...                    ...    ...     ...  ...     ...      ...      ...
# 768  698                 Amaura   Rock     Ice   77      59       50       67
# 769  699                Aurorus   Rock     Ice  123      77       72       99
# 773  703                Carbink   Rock   Fairy   50      50      150       50
# 795  719                Diancie   Rock   Fairy   50     100      150      100
# 796  719    DiancieMega Diancie   Rock   Fairy   50     160      110      160
#
# ...

# %%
pokemon
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# # .isnull() and .notnull() method

# %%
mask1=pokemon["Attack"].isnull()  # it return boolean result
pokemon[mask1] # no reult because it will True result but over dataframe does npt have True value thats why
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary]
# Index: []

# %%
mask1=pokemon["Attack"].notnull()  # it return boolean result
pokemon[mask1] # no value is null hats why
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# # .between() method

# %%
# if our date is like this 2012-12-12 12:00:00 then we write like this  12:00PM for bwtween method
pokemon[pokemon["Attack"].between(50,60)]  #start and end  and 50 and 60 are included
# Out:
#        #        Name    Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 4      4  Charmander      Fire     NaN  39      52       43       60       50
# 21    17   Pidgeotto    Normal  Flying  63      60       55       50       50
# 24    19     Rattata    Normal     NaN  30      56       35       25       35
# 26    21     Spearow    Normal  Flying  40      60       30       31       31
# 28    23       Ekans    Poison     NaN  35      60       44       40       54
# ..   ...         ...       ...     ...  ..     ...      ...      ...      ...
# 765  695   Heliolisk  Electric  Normal  62      55       52      109       94
# 768  698      Amaura      Rock     Ice  77      59       50       67       63
# 772  702     Dedenne  Electric   Fairy  67      58       57       81       67
# 773  703     Carbink      Rock   Fairy  50      50      150       50      150
# 774  704       Goomy    Dragon     NaN  45      50       35       55       75
#
# ...

# %%
pokemon["Type 1"].duplicated()  # in this keep ="first" by default means it see Grass for first time so thats not duplate but 
#after that it is duplicated means condition is true
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 795     True
# 796     True
# 797     True
# 798     True
# 799     True
# Name: Type 1, Length: 800, dtype: bool

# %%
pokemon["Type 1"].duplicated(keep="last") # noe last occurance of typ1 value is not duplicate and rest is True(Measn duplcate)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 795     True
# 796    False
# 797     True
# 798    False
# 799    False
# Name: Type 1, Length: 800, dtype: bool

# %%
pokemon["Type 1"].duplicated(keep=False) # measn all are duplcate
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 795    True
# 796    True
# 797    True
# 798    True
# 799    True
# Name: Type 1, Length: 800, dtype: bool

# %%
pokemon["Type 1"].duplicated(keep=True) # it expect first and last and False argument value
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-e7857f193b51> in <module>
# ----> 1 pokemon["Type 1"].duplicated(keep=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in duplicated(self, keep)
#    2137         dtype: bool
#    2138         """
# -> 2139         return super().duplicated(keep=keep)
#    2140
#    2141     def idxmin(self, axis=0, skipna=True, *args, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in duplicated(self, keep)
#    1640         else:
#    1641             return self._constructor(
# -> 1642                 duplicated(self, keep=keep), index=self.index
#    1643             ).__finalize__(self)
#    1644
#
# ~\Anaconda3\lib\site-packages\pandas\core\algorithms.py in duplicated(values, keep)
#     837     values, dtype, ndtype = _ensure_data(values)
# ...

# %%
~pokemon["Type 1"].duplicated(keep=False) # i have put negation symbol at the begining odf command to negate
# if our result is true thenit will produce false

# %%
new1=~pokemon["Type 1"].duplicated()
pokemon[new1]  # think for this
# Out:
#        #                     Name    Type 1   Type 2  HP  Attack  Defense  \
# 0      1                Bulbasaur     Grass   Poison  45      49       49
# 4      4               Charmander      Fire      NaN  39      52       43
# 9      7                 Squirtle     Water      NaN  44      48       65
# 13    10                 Caterpie       Bug      NaN  45      30       35
# 20    16                   Pidgey    Normal   Flying  40      45       40
# 28    23                    Ekans    Poison      NaN  35      60       44
# 30    25                  Pikachu  Electric      NaN  35      55       40
# 32    27                Sandshrew    Ground      NaN  50      75       85
# 40    35                 Clefairy     Fairy      NaN  70      45       48
# 61    56                   Mankey  Fighting      NaN  40      80       35
# 68    63                     Abra   Psychic      NaN  25      20       15
# 80    74                  Geodude      Rock   Ground  40      80      100
# ...

# %%
pokemon.drop_duplicates()  # measn no two rows are same
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# # drop_duplicates

# %%
pokemon.drop_duplicates(subset=["Type 1"]) # by default keep is first is set
# Out:
#        #                     Name    Type 1   Type 2  HP  Attack  Defense  \
# 0      1                Bulbasaur     Grass   Poison  45      49       49
# 4      4               Charmander      Fire      NaN  39      52       43
# 9      7                 Squirtle     Water      NaN  44      48       65
# 13    10                 Caterpie       Bug      NaN  45      30       35
# 20    16                   Pidgey    Normal   Flying  40      45       40
# 28    23                    Ekans    Poison      NaN  35      60       44
# 30    25                  Pikachu  Electric      NaN  35      55       40
# 32    27                Sandshrew    Ground      NaN  50      75       85
# 40    35                 Clefairy     Fairy      NaN  70      45       48
# 61    56                   Mankey  Fighting      NaN  40      80       35
# 68    63                     Abra   Psychic      NaN  25      20       15
# 80    74                  Geodude      Rock   Ground  40      80      100
# ...

# %%
pokemon.drop_duplicates(subset=["Type 1","Type 2"]) # work on multiple value
# Out:
#        #                       Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1                  Bulbasaur    Grass  Poison  45      49       49
# 4      4                 Charmander     Fire     NaN  39      52       43
# 6      6                  Charizard     Fire  Flying  78      84       78
# 7      6  CharizardMega Charizard X     Fire  Dragon  78     130      111
# 9      7                   Squirtle    Water     NaN  44      48       65
# ..   ...                        ...      ...     ...  ..     ...      ...
# 778  708                   Phantump    Ghost   Grass  43      70       48
# 790  714                     Noibat   Flying  Dragon  40      30       35
# 797  720        HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720         HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721                  Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# # .unique() and nunique()

# %%
# but firstly .nunique() methid by default has dropna=true , which measn it exclued na value automatically
pokemon["Type 1"].unique()   # it represent array
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
len(pokemon["Type 1"].unique())
# Out:
# 18

# %%
pokemon["Type 1"].nunique() # by deafult dropna=True measn if our daaset has NaN value then it will remove automatically
# if NaN is present then output would be 17
#nunique() n repesent number of unique
# Out:
# 18
