# %%
import pandas as pd

# %%
pokemon=pd.read_excel(r"C:\Users\Ajay\Desktop\pokemon_data.xlsx")
pokemon
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
pokemon.values  # it provide all value without column name
# Out:
# array([[1, 'Bulbasaur', 'Grass', ..., 45, 1, False],
#        [2, 'Ivysaur', 'Grass', ..., 60, 1, False],
#        [3, 'Venusaur', 'Grass', ..., 80, 1, False],
#        ...,
#        [720, 'HoopaHoopa Confined', 'Psychic', ..., 70, 6, True],
#        [720, 'HoopaHoopa Unbound', 'Psychic', ..., 80, 6, True],
#        [721, 'Volcanion', 'Fire', ..., 70, 6, True]], dtype=object)

# %%
pokemon.index  # rangeindex object
# Out:
# RangeIndex(start=0, stop=800, step=1)

# %%
pokemon.dtypes  # for multiple columns , so i used S at the end
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
pokemon.isnull
# Out:
# <bound method DataFrame.isnull of                       Name
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# ..                     ...
# 795                Diancie
# 796    DiancieMega Diancie
# 797    HoopaHoopa Confined
# 798     HoopaHoopa Unbound
# 799              Volcanion
#
# [800 rows x 1 columns]>

# %%
pokemon.ndim  # 2 dimentional array
# Out:
# 2

# %%
pokemon.shape  # row and column
# it is tuple
# in this case we have one column
# Out:
# (800, 1)

# %%
pokemon.size  # row
# it count null value
# Out:
# 800

# %%
pokemon.nunique  # return  unique item
# Out:
# <bound method DataFrame.nunique of                       Name
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# ..                     ...
# 795                Diancie
# 796    DiancieMega Diancie
# 797    HoopaHoopa Confined
# 798     HoopaHoopa Unbound
# 799              Volcanion
#
# [800 rows x 1 columns]>

# %%
pokemon.head()
# Out:
#                     Name
# 0              Bulbasaur
# 1                Ivysaur
# 2               Venusaur
# 3  VenusaurMega Venusaur
# 4             Charmander

# %%
pokemon.name="pokename_rename"

# %% [markdown]
# #  .sort_values() method

# %%
pokemon.sort_values("Name")
# Out:
#                         Name
# 510                Abomasnow
# 511  AbomasnowMega Abomasnow
# 68                      Abra
# 392                    Absol
# 393          AbsolMega Absol
# ..                       ...
# 632                  Zoroark
# 631                    Zorua
# 46                     Zubat
# 695                 Zweilous
# 794         Zygarde50% Forme
#
# [800 rows x 1 columns]

# %%
pokemon.sort_values("Name").head()
# Out:
#                         Name
# 510                Abomasnow
# 511  AbomasnowMega Abomasnow
# 68                      Abra
# 392                    Absol
# 393          AbsolMega Absol

# %%
pokemon.sort_values("Name",ascending=False).head()  # decending order
# Out:
#                  Name
# 794  Zygarde50% Forme
# 695          Zweilous
# 46              Zubat
# 631             Zorua
# 632           Zoroark

# %%
pokemon.sort_values("Name",ascending=False).tail()
# Out:
#                         Name
# 393          AbsolMega Absol
# 392                    Absol
# 68                      Abra
# 511  AbomasnowMega Abomasnow
# 510                Abomasnow

# %% [markdown]
# # inplace parameter

# %%
pokemon=pokemon.sort_values("Name",ascending=False).tail()   #i saved my logic in same file

# %%
pokemon
# Out:
#                         Name
# 393          AbsolMega Absol
# 392                    Absol
# 68                      Abra
# 511  AbomasnowMega Abomasnow
# 510                Abomasnow

# %%
pokemon.sort_values("Name",inplace=True)
# now out data is override becasue of inplace  argumnets
# by default inplace is false

# %%
pokemon
# Out:
#                         Name
# 510                Abomasnow
# 511  AbomasnowMega Abomasnow
# 68                      Abra
# 392                    Absol
# 393          AbsolMega Absol

# %% [markdown]
# # .sort_index() method

# %%
pokemon=pd.read_excel(r"C:\Users\Ajay\Desktop\pokemon_data.xlsx")
pokemon
pokemon.sort_values("Name",inplace=False)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
pokemon.sort_index(ascending=False,inplace=True)

# %%
pokemon
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 799  721              Volcanion     Fire   Water  80     110      120
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 795  719                Diancie     Rock   Fairy  50     100      150
# ..   ...                    ...      ...     ...  ..     ...      ...
# 4      4             Charmander     Fire     NaN  39      52       43
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 2      3               Venusaur    Grass  Poison  80      82       83
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 0      1              Bulbasaur    Grass  Poison  45      49       49
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 799      130       90     70           6       True
# ...

# %% [markdown]
# # python in keywod

# %%
1 in [1,2,3,4]
# Out:
# True

# %%
1 in (1,2,3,4)
# Out:
# True

# %%
1 in [0,2,3,4]
# Out:
# False

# %%
pokemon.head()
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 799  721            Volcanion     Fire  Water  80     110      120      130
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 795  719              Diancie     Rock  Fairy  50     100      150      100
#
#      Sp. Def  Speed  Generation  Legendary
# 799       90     70           6       True
# 798      130     80           6       True
# 797      130     70           6       True
# 796      110    110           6       True
# 795      150     50           6       True

# %%
"Volcanion" in pokemon # becasue it is looking index column ,not Name column
# Out:
# False

# %%
"Volcanion" in pokemon.values
# Out:
# True
