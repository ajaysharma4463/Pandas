# %%
import pandas as pd
pokemon=pd.read_excel(r"C:\Users\Ajay\Desktop\pokemon_data.xlsx")
pokemon  # index_col="Name"  for putting column in top side
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# # set_index() and rest_index() methos

# %%
pokemon.set_index("Name",inplace=True)  # it is simmilar to index_cols method
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-d0a5c5884fed> in <module>
# ----> 1 pokemon.set_index("Name",inplace=True)  # it is simmilar to index_cols method
#       2 pokemon
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4394
#    4395         if missing:
# -> 4396             raise KeyError("None of {} are in the columns".format(missing))
#    4397
#    4398         if inplace:
#
# KeyError: "None of ['Name'] are in the columns"

# %%
pokemon
# Out:
#                          #   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur                1    Grass  Poison  45      49       49       65
# Ivysaur                  2    Grass  Poison  60      62       63       80
# Venusaur                 3    Grass  Poison  80      82       83      100
# VenusaurMega Venusaur    3    Grass  Poison  80     100      123      122
# Charmander               4     Fire     NaN  39      52       43       60
# ...                    ...      ...     ...  ..     ...      ...      ...
# Diancie                719     Rock   Fairy  50     100      150      100
# DiancieMega Diancie    719     Rock   Fairy  50     160      110      160
# HoopaHoopa Confined    720  Psychic   Ghost  80     110       60      150
# HoopaHoopa Unbound     720  Psychic    Dark  80     160       60      170
# Volcanion              721     Fire   Water  80     110      120      130
#
#                        Sp. Def  Speed  Generation  Legendary
# Name
# ...

# %%
pokemon.reset_index(drop=False)
# Out:
#                       Name    #   Type 1  Type 2  HP  Attack  Defense  \
# 0                Bulbasaur    1    Grass  Poison  45      49       49
# 1                  Ivysaur    2    Grass  Poison  60      62       63
# 2                 Venusaur    3    Grass  Poison  80      82       83
# 3    VenusaurMega Venusaur    3    Grass  Poison  80     100      123
# 4               Charmander    4     Fire     NaN  39      52       43
# ..                     ...  ...      ...     ...  ..     ...      ...
# 795                Diancie  719     Rock   Fairy  50     100      150
# 796    DiancieMega Diancie  719     Rock   Fairy  50     160      110
# 797    HoopaHoopa Confined  720  Psychic   Ghost  80     110       60
# 798     HoopaHoopa Unbound  720  Psychic    Dark  80     160       60
# 799              Volcanion  721     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
pokemon.reset_index() # everything is roll back
# Out:
#                       Name    #   Type 1  Type 2  HP  Attack  Defense  \
# 0                Bulbasaur    1    Grass  Poison  45      49       49
# 1                  Ivysaur    2    Grass  Poison  60      62       63
# 2                 Venusaur    3    Grass  Poison  80      82       83
# 3    VenusaurMega Venusaur    3    Grass  Poison  80     100      123
# 4               Charmander    4     Fire     NaN  39      52       43
# ..                     ...  ...      ...     ...  ..     ...      ...
# 795                Diancie  719     Rock   Fairy  50     100      150
# 796    DiancieMega Diancie  719     Rock   Fairy  50     160      110
# 797    HoopaHoopa Confined  720  Psychic   Ghost  80     110       60
# 798     HoopaHoopa Unbound  720  Psychic    Dark  80     160       60
# 799              Volcanion  721     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
pokemon.set_index("Type 1")  # now in this we lost Name column so slwaasy use rest_index after set_index
# Out:
#            #  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Grass      1  Poison  45      49       49       65       65     45
# Grass      2  Poison  60      62       63       80       80     60
# Grass      3  Poison  80      82       83      100      100     80
# Grass      3  Poison  80     100      123      122      120     80
# Fire       4     NaN  39      52       43       60       50     65
# ...      ...     ...  ..     ...      ...      ...      ...    ...
# Rock     719   Fairy  50     100      150      100      150     50
# Rock     719   Fairy  50     160      110      160      110    110
# Psychic  720   Ghost  80     110       60      150      130     70
# Psychic  720    Dark  80     160       60      170      130     80
# Fire     721   Water  80     110      120      130       90     70
#
#          Generation  Legendary
# Type 1
# Grass             1      False
# Grass             1      False
# Grass             1      False
# ...

# %%
pokemon.set_index("Type 1" ,inplace=True)

# %%
pokemon.reset_index( inplace=True)

# %%
pokemon.set_index("Type 2" ,inplace=True)

# %%
pokemon  # all lst 3 command is useful  ,we didnt lose Type 1 column becasue we rest before we want to change it to another
# Out:
#          Type 1    #  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 2
# Poison    Grass    1  45      49       49       65       65     45
# Poison    Grass    2  60      62       63       80       80     60
# Poison    Grass    3  80      82       83      100      100     80
# Poison    Grass    3  80     100      123      122      120     80
# NaN        Fire    4  39      52       43       60       50     65
# ...         ...  ...  ..     ...      ...      ...      ...    ...
# Fairy      Rock  719  50     100      150      100      150     50
# Fairy      Rock  719  50     160      110      160      110    110
# Ghost   Psychic  720  80     110       60      150      130     70
# Dark    Psychic  720  80     160       60      170      130     80
# Water      Fire  721  80     110      120      130       90     70
#
#         Generation  Legendary
# Type 2
# Poison           1      False
# Poison           1      False
# Poison           1      False
# ...

# %% [markdown]
# # .loc() method

# %%
pokemon.sort_index(inplace=True)
pokemon.head()  # sorting has been done for column type 1
# Out:
#         Type 1    #  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Type 2
# Bug       Rock  348  75     125      100       70       80     45           3
# Bug       Rock  347  45      95       50       40       50     75           3
# Bug     Poison  451  40      50       90       30       55     65           4
# Dark     Grass  275  90     100       60       90       60     80           3
# Dark    Poison  452  70      90      110       60       75     95           4
#
#         Legendary
# Type 2
# Bug         False
# Bug         False
# Bug         False
# Dark        False
# Dark        False

# %%
# .loc methos can be used with dataframe 
#.loc[] used paranthese to maintain retrivwing data

pokemon.loc["Bug"] # if pandas find Bug more than one then it willprdude datafrmane rather than seriess
# Out:
#         Type 1    #  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Type 2
# Bug       Rock  348  75     125      100       70       80     45           3
# Bug       Rock  347  45      95       50       40       50     75           3
# Bug     Poison  451  40      50       90       30       55     65           4
#
#         Legendary
# Type 2
# Bug         False
# Bug         False
# Bug         False

# %%
pokemon.loc["Bug":"Water"]  # what come in between
# Out:
#         Type 1    #  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Type 2
# Bug       Rock  348  75     125      100       70       80     45           3
# Bug       Rock  347  45      95       50       40       50     75           3
# Bug     Poison  451  40      50       90       30       55     65           4
# Dark     Grass  275  90     100       60       90       60     80           3
# Dark    Poison  452  70      90      110       60       75     95           4
# ...        ...  ...  ..     ...      ...      ...      ...    ...         ...
# Water      Ice  363  70      40       50       55       50     25           3
# Water      Bug  283  40      30       32       50       52     65           3
# Water     Rock  688  42      52       67       39       56     50           6
# Water     Rock  138  35      40      100       90       55     35           1
# Water     Fire  721  80     110      120      130       90     70           6
#
#         Legendary
# ...

# %%
pokemon.loc["Bug":"Water"]
# Out:
#         Type 1    #  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Type 2
# Bug       Rock  348  75     125      100       70       80     45           3
# Bug       Rock  347  45      95       50       40       50     75           3
# Bug     Poison  451  40      50       90       30       55     65           4
# Dark     Grass  275  90     100       60       90       60     80           3
# Dark    Poison  452  70      90      110       60       75     95           4
# ...        ...  ...  ..     ...      ...      ...      ...    ...         ...
# Water      Ice  363  70      40       50       55       50     25           3
# Water      Bug  283  40      30       32       50       52     65           3
# Water     Rock  688  42      52       67       39       56     50           6
# Water     Rock  138  35      40      100       90       55     35           1
# Water     Fire  721  80     110      120      130       90     70           6
#
#         Legendary
# ...

# %% [markdown]
# #  retrive ros by index position with i loc

# %%
# iloc stand for index location
pokemon.iloc[12]
# Out:
# Type 1        Water
# #               658
# HP               72
# Attack           95
# Defense          67
# Sp. Atk         103
# Sp. Def          71
# Speed           122
# Generation        6
# Legendary     False
# Name: Dark, dtype: object

# %%
pokemon.iloc[[12,13]]
# Out:
#         Type 1    #  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Type 2
# Dark     Water  658  72      95       67      103       71    122           6
# Dark    Ground  551  50      72       35       35       35     65           5
#
#         Legendary
# Type 2
# Dark        False
# Dark        False

# %% [markdown]
# # .ix[] method

# %%
pokemon.ix["Dark"]
pokemon.loc["Dark"]
# Out:
# C:\Users\Ajay\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#           Type 1    #   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 2
# Dark       Grass  275   90     100       60       90       60     80
# Dark      Poison  452   70      90      110       60       75     95
# Dark       Ghost  442   50      92      108       92      108     35
# Dark        Rock  248  100     134      110       95      100     61
# Dark        Rock  248  100     164      150       95      120     71
# Dark      Poison  435  103      93       67       71       61     84
# Dark      Poison  434   63      63       47       41       41     74
# ...

# %%
pokemon.iloc[12]
# Out:
# Type 1        Water
# #               658
# HP               72
# Attack           95
# Defense          67
# Sp. Atk         103
# Sp. Def          71
# Speed           122
# Generation        6
# Legendary     False
# Name: Dark, dtype: object

# %%
pokemon.ix[["Dark","Work"]]   # work is incorrect value that wh error
# Out:
# C:\Users\Ajay\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-f5eeceb3254f> in <module>
# ----> 1 pokemon.ix[["Dark","Work"]]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     146
#     147             key = com.apply_if_callable(key, self.obj)
# --> 148             return self._getitem_axis(key, axis=axis)
#     149
#     150     def _get_label(self, label, axis: int):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
# ...

# %%
pokemon.ix[12]
# Out:
# C:\Users\Ajay\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# Type 1        Water
# #               658
# HP               72
# Attack           95
# Defense          67
# Sp. Atk         103
# Sp. Def          71
# Speed           122
# Generation        6
# Legendary     False
# Name: Dark, dtype: object

# %% [markdown]
# # second argument in .iloc[] and loc[] and ix[]

# %%
pokemon.head(4)
# Out:
#         Type 1    #  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Type 2
# Bug       Rock  348  75     125      100       70       80     45           3
# Bug       Rock  347  45      95       50       40       50     75           3
# Bug     Poison  451  40      50       90       30       55     65           4
# Dark     Grass  275  90     100       60       90       60     80           3
#
#         Legendary
# Type 2
# Bug         False
# Bug         False
# Bug         False
# Dark        False

# %%
pokemon.loc["Bug","Attack"]   # second argumnet is column
# Out:
# Type 2
# Bug    125
# Bug     95
# Bug     50
# Name: Attack, dtype: int64

# %%
pokemon.loc["Bug","Defense":"Speed"]  # i used colun
# Out:
#         Defense  Sp. Atk  Sp. Def  Speed
# Type 2
# Bug         100       70       80     45
# Bug          50       40       50     75
# Bug          90       30       55     65

# %%
pokemon.loc["Bug",["Defense","Speed"]]  # i provide list
# Out:
#         Defense  Speed
# Type 2
# Bug         100     45
# Bug          50     75
# Bug          90     65

# %%
pokemon.iloc[14,2]  # i thnk it work on index i guues
# and we can use list and coluns , just like previous code
# Out:
# 45

# %%
pokemon.ix[12,"Defense"] # i can mix in this
# Out:
# C:\Users\Ajay\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# C:\Users\Ajay\Anaconda3\lib\site-packages\pandas\core\indexing.py:961: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   return getattr(section, self.name)[new_key]
# 67

# %% [markdown]
# # set new value in row and specific cell

# %%
pokemon.ix[12]
# Out:
# C:\Users\Ajay\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# Type 1        Water
# #               658
# HP               72
# Attack           95
# Defense          67
# Sp. Atk         103
# Sp. Def          71
# Speed           122
# Generation        6
# Legendary     False
# Name: Dark, dtype: object

# %%
pokemon.ix[12,"Attack"]
# Out:
# C:\Users\Ajay\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# C:\Users\Ajay\Anaconda3\lib\site-packages\pandas\core\indexing.py:961: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   return getattr(section, self.name)[new_key]
# 95

# %%
pokemon.ix[12,"Attack"]=100
# Out:
# C:\Users\Ajay\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
pokemon.ix[12,"Attack"]  # it worked
# Out:
# C:\Users\Ajay\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 100

# %%
pokemon.ix[12,["Attack","Generation"]]=[21212,12212]
# Out:
# C:\Users\Ajay\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
pokemon.ix[12,["Attack","Generation"]]   # for modification just provide list in it
# Out:
# C:\Users\Ajay\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# Attack        21212
# Generation    12212
# Name: Dark, dtype: object

# %% [markdown]
# #  rename column name in panda dataframe

# %%
pokemon.rename(columns={"Attack":"Killer"},inplace=True)  # i have used dictionary for rem=naming

# %%
pokemon.head()  # name has been chage
# Out:
#         Type 1    #  HP  Killer  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Type 2
# Bug       Rock  348  75     125      100       70       80     45           3
# Bug       Rock  347  45      95       50       40       50     75           3
# Bug     Poison  451  40      50       90       30       55     65           4
# Dark     Grass  275  90     100       60       90       60     80           3
# Dark    Poison  452  70      90      110       60       75     95           4
#
#         Legendary
# Type 2
# Bug         False
# Bug         False
# Bug         False
# Dark        False
# Dark        False

# %%
pokemon.rename(index={"Bug":"New bug",
                     "Dark":"new dark"},inplace=True)  # index is chaged

# %%
pokemon.head()
# Out:
#           Type 1    #  HP  Killer  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 2
# New bug     Rock  348  75     125      100       70       80     45
# New bug     Rock  347  45      95       50       40       50     75
# New bug   Poison  451  40      50       90       30       55     65
# new dark   Grass  275  90     100       60       90       60     80
# new dark  Poison  452  70      90      110       60       75     95
#
#           Generation  Legendary
# Type 2
# New bug            3      False
# New bug            3      False
# New bug            4      False
# new dark           3      False
# new dark           4      False

# %%
# another wasy to chage column name
pokemon.columns
# Out:
# Index(['Type 1', '#', 'HP', 'Killer', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed',
#        'Generation', 'Legendary'],
#       dtype='object')

# %%
pokemon.columns=['Type 112', '#', 'HP', 'Killer', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed',
       'Generation', 'Legendary']

# %%
pokemon.head(12)   # column nameis chaged
# and we need to maintain the order otherwise it will give error
# write column name properly otherwizw incorrect colun name wil be displayed
# Out:
#          Type 112    #   HP  Killer  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 2
# New bug      Rock  348   75     125      100       70       80     45
# New bug      Rock  347   45      95       50       40       50     75
# New bug    Poison  451   40      50       90       30       55     65
# new dark    Grass  275   90     100       60       90       60     80
# new dark   Poison  452   70      90      110       60       75     95
# new dark    Ghost  442   50      92      108       92      108     35
# new dark     Rock  248  100     134      110       95      100     61
# new dark     Rock  248  100     164      150       95      120     71
# new dark   Poison  435  103      93       67       71       61     84
# new dark   Poison  434   63      63       47       41       41     74
# new dark    Grass  274   70      70       40       60       40     60
# new dark   Ground  552   60      82       45       45       45     74
#
#           Generation  Legendary
# Type 2
# ...

# %% [markdown]
# # how to delete row and column in dataframe

# %%
pokemon.drop("New bug")   # we can aloso provide index value in it
# Out:
#          Type 112    #   HP  Killer  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 2
# new dark    Grass  275   90     100       60       90       60     80
# new dark   Poison  452   70      90      110       60       75     95
# new dark    Ghost  442   50      92      108       92      108     35
# new dark     Rock  248  100     134      110       95      100     61
# new dark     Rock  248  100     164      150       95      120     71
# ...           ...  ...  ...     ...      ...      ...      ...    ...
# NaN        Dragon  705   68      75       53       83      113     60
# NaN        Dragon  706   90     100       70      110      150     80
# NaN           Ice  712   55      69       85       32       35     28
# NaN           Ice  713   95     117      184       44       46     28
# NaN         Fairy  716  126     131       95      131       98     99
#
#           Generation  Legendary
# Type 2
# new dark           3      False
# new dark           4      False
# ...

# %%
pokemon.head()
# Out:
#          Type 112    #  HP  Killer  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 2
# New bug      Rock  348  75     125      100       70       80     45
# New bug      Rock  347  45      95       50       40       50     75
# New bug    Poison  451  40      50       90       30       55     65
# new dark    Grass  275  90     100       60       90       60     80
# new dark   Poison  452  70      90      110       60       75     95
#
#           Generation  Legendary
# Type 2
# New bug            3      False
# New bug            3      False
# New bug            4      False
# new dark           3      False
# new dark           4      False

# %%
pokemon.drop(["New bug","new dark"])
# Out:
#        Type 112    #   HP  Killer  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 2
# Dragon    Steel  483  100     120      120      150      100     90
# Dragon   Flying  714   40      30       35       45       40     55
# Dragon   Flying  715   85      70       80       97       80    123
# Dragon   Poison  691   65      75       90       97      123     44
# Dragon     Dark  633   52      65       50       45       50     38
# ...         ...  ...  ...     ...      ...      ...      ...    ...
# NaN      Dragon  705   68      75       53       83      113     60
# NaN      Dragon  706   90     100       70      110      150     80
# NaN         Ice  712   55      69       85       32       35     28
# NaN         Ice  713   95     117      184       44       46     28
# NaN       Fairy  716  126     131       95      131       98     99
#
#         Generation  Legendary
# Type 2
# Dragon           4       True
# Dragon           6      False
# Dragon           6      False
# ...

# %%
# for deleting column, we need to use asis to 1 becasue by default it is 0
pokemon.drop("Type 112",axis=1)
# it worked axis="columns"
# for row  axis=0 or axis=rows or axis=index
# Out:
#             #   HP  Killer  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Type 2
# New bug   348   75     125      100       70       80     45           3
# New bug   347   45      95       50       40       50     75           3
# New bug   451   40      50       90       30       55     65           4
# new dark  275   90     100       60       90       60     80           3
# new dark  452   70      90      110       60       75     95           4
# ...       ...  ...     ...      ...      ...      ...    ...         ...
# NaN       705   68      75       53       83      113     60           6
# NaN       706   90     100       70      110      150     80           6
# NaN       712   55      69       85       32       35     28           6
# NaN       713   95     117      184       44       46     28           6
# NaN       716  126     131       95      131       98     99           6
#
#           Legendary
# Type 2
# New bug       False
# New bug       False
# ...

# %%
# another method is pop()
# no need to use inplace ,it automaticlly save it
# it will delete the result and show as well which mean we can store for future references
killer=pokemon.pop("Killer")

# %%
pokemon
# Out:
#          Type 112    #   HP  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Type 2
# New bug      Rock  348   75      100       70       80     45           3
# New bug      Rock  347   45       50       40       50     75           3
# New bug    Poison  451   40       90       30       55     65           4
# new dark    Grass  275   90       60       90       60     80           3
# new dark   Poison  452   70      110       60       75     95           4
# ...           ...  ...  ...      ...      ...      ...    ...         ...
# NaN        Dragon  705   68       53       83      113     60           6
# NaN        Dragon  706   90       70      110      150     80           6
# NaN           Ice  712   55       85       32       35     28           6
# NaN           Ice  713   95      184       44       46     28           6
# NaN         Fairy  716  126       95      131       98     99           6
#
#           Legendary
# Type 2
# New bug       False
# ...

# %%
killer
# Out:
# Type 2
# New bug     125
# New bug      95
# New bug      50
# new dark    100
# new dark     90
#            ...
# NaN          75
# NaN         100
# NaN          69
# NaN         117
# NaN         131
# Name: Killer, Length: 800, dtype: int64

# %%
# another metho to deleter by using del keyword
del pokemon["HP"]

# %%
pokemon  # it worked
# Out:
#          Type 112    #  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Type 2
# New bug      Rock  348      100       70       80     45           3
# New bug      Rock  347       50       40       50     75           3
# New bug    Poison  451       90       30       55     65           4
# new dark    Grass  275       60       90       60     80           3
# new dark   Poison  452      110       60       75     95           4
# ...           ...  ...      ...      ...      ...    ...         ...
# NaN        Dragon  705       53       83      113     60           6
# NaN        Dragon  706       70      110      150     80           6
# NaN           Ice  712       85       32       35     28           6
# NaN           Ice  713      184       44       46     28           6
# NaN         Fairy  716       95      131       98     99           6
#
#           Legendary
# Type 2
# New bug       False
# New bug       False
# New bug       False
# new dark      False
# ...

# %% [markdown]
# # create randam sample

# %%
pokemon.sample()  # everytime it will produce diferent row
# Out:
#        Type 112    #  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Type 2
# Dragon    Water  484      100      150      120    100           4       True

# %%
pokemon.sample(3)
# Out:
#        Type 112    #  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Type 2
# Flying      Bug  414       50       94       50     66           4      False
# Flying    Fairy  468       95      120      115     80           4      False
# Fire       Dark  228       30       80       50     65           2      False

# %%
pokemon.sample(n=3)
# Out:
#        Type 112    #  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Type 2
# Grass     Ghost  710       70       44       55     41           6      False
# NaN       Water  419       55       85       50    115           4      False
# NaN      Normal  288       80       55       55     90           3      False

# %%
pokemon.sample(frac=0.25)
# Out:
#         Type 112    #  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Type 2
# Fire        Dark  229       90      140       90    115           2      False
# NaN        Water  656       40       62       44     71           6      False
# Poison     Grass  590       45       55       55     15           5      False
# NaN     Fighting  620       60       95       60    105           5      False
# NaN     Fighting  297       60       40       60     50           3      False
# ...          ...  ...      ...      ...      ...    ...         ...        ...
# NaN       Normal  242       10       75      135     55           2      False
# Rock      Ground  464      130       55       55     40           4      False
# NaN         Fire  513       48       53       48     64           5      False
# NaN       Dragon  704       35       55       75     40           6      False
# NaN        Ghost  356      130       60      130     25           3      False
#
# ...

# %%
pokemon.sample(3,axis=1)  # three randow columns
# Out:
#           Speed Type 112  Sp. Atk
# Type 2
# New bug      45     Rock       70
# New bug      75     Rock       40
# New bug      65   Poison       30
# new dark     80    Grass       90
# new dark     95   Poison       60
# ...         ...      ...      ...
# NaN          60   Dragon       83
# NaN          80   Dragon      110
# NaN          28      Ice       32
# NaN          28      Ice       44
# NaN          99    Fairy      131
#
# [800 rows x 3 columns]

# %% [markdown]
# # .nsmallest() and nlargest() methd

# %%
pokemon.sort_values("Speed" ,ascending=False).head(3)
# Out:
#        Type 112    #  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Type 2
# NaN     Psychic  386       90       95       90    180           3       True
# Flying      Bug  291       45       50       50    160           3      False
# NaN     Psychic  386       20      180       20    150           3       True

# %%
pokemon.nlargest(4,"Defense")  # it provide 4 highest number
# Out:
#        Type 112    #  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Type 2
# Ground    Steel  208      230       55       95     30           2      False
# Rock        Bug  213      230       10      230      5           2      False
# NaN       Steel  306      230       60       80     50           3      False
# Ground    Steel  208      200       55       65     30           2      False

# %%
pokemon.nlargest(4,columns="Defense")   # same result
# Out:
#        Type 112    #  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Type 2
# Ground    Steel  208      230       55       95     30           2      False
# Rock        Bug  213      230       10      230      5           2      False
# NaN       Steel  306      230       60       80     50           3      False
# Ground    Steel  208      200       55       65     30           2      False

# %%
pokemon.nsmallest(3,columns="Defense")
# Out:
#        Type 112    #  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Type 2
# NaN      Normal  113        5       35      105     50           1      False
# NaN      Normal  440        5       15       65     30           4      False
# NaN      Normal  242       10       75      135     55           2      False

# %%
pokemon["Speed"].nlargest(3) # another way
# Out:
# Type 2
# NaN       180
# Flying    160
# Flying    150
# Name: Speed, dtype: int64

# %% [markdown]
# # filtering with where method

# %%
pokemon=pd.read_excel(r"C:\Users\Ajay\Desktop\pokemon_data.xlsx")
pokemon
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
new1=pokemon["Name"]=="Bulbasaur"
pokemon.where(new1)  # where methos print those value in this condition is true and rest of the value will be show in NaN
# we can also use &, or
# Out:
#        #       Name Type 1  Type 2    HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0    1.0  Bulbasaur  Grass  Poison  45.0    49.0     49.0     65.0     65.0
# 1    NaN        NaN    NaN     NaN   NaN     NaN      NaN      NaN      NaN
# 2    NaN        NaN    NaN     NaN   NaN     NaN      NaN      NaN      NaN
# 3    NaN        NaN    NaN     NaN   NaN     NaN      NaN      NaN      NaN
# 4    NaN        NaN    NaN     NaN   NaN     NaN      NaN      NaN      NaN
# ..   ...        ...    ...     ...   ...     ...      ...      ...      ...
# 795  NaN        NaN    NaN     NaN   NaN     NaN      NaN      NaN      NaN
# 796  NaN        NaN    NaN     NaN   NaN     NaN      NaN      NaN      NaN
# 797  NaN        NaN    NaN     NaN   NaN     NaN      NaN      NaN      NaN
# 798  NaN        NaN    NaN     NaN   NaN     NaN      NaN      NaN      NaN
# 799  NaN        NaN    NaN     NaN   NaN     NaN      NaN      NaN      NaN
#
#      Speed  Generation  Legendary
# ...

# %% [markdown]
# # .query methd

# %%
#.query methos can apllied on dataframe
# it doesnot work with column name which has two name like firatname and lastname
pokemon.query("Name=='Bulbasaur'")  # we can prove diferent quotes
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
#
#    Generation  Legendary
# 0           1      False

# %%
pokemon.query("Name !='Bulbasaur'")
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# 5      5             Charmeleon     Fire     NaN  58      64       58
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 1         80       80     60           1      False
# ...

# %%
pokemon.query("Name !='Bulbasaur' or Name =='Bulbasaur'")    #We can use and ,or  rather than &
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
pokemon.query("Name in ['Bulbasaur','Charmander'] ")
# Out:
#    #        Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1   Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 4  4  Charmander   Fire     NaN  39      52       43       60       50     65
#
#    Generation  Legendary
# 0           1      False
# 4           1      False

# %%
pokemon.query("Name not in ['Bulbasaur','Charmander'] ")
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 5      5             Charmeleon     Fire     NaN  58      64       58
# 6      6              Charizard     Fire  Flying  78      84       78
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 1         80       80     60           1      False
# ...

# %% [markdown]
# # .copy methos

# %%
#copy the series or dartaframe with different location
# whenever we want to work on few column rather than dataframe, we nned to take important column and use coppy method as ell

# %%
pokemons=pokemon["Name"].copy()   # creating a new variable with series in it

# %%
pokemons[0]="new Bulbasaur"   # aceesing through index

# %%
pokemons.head(3)  # it updated
# Out:
# 0    new Bulbasaur
# 1          Ivysaur
# 2         Venusaur
# Name: Name, dtype: object

# %%
pokemon.head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False
